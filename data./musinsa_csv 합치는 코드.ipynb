# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# 코랩에서 바로 파일을 가져오려면, 위의 google.colab 드라이브로 마운트하신 다음, 본인의 MyDrive에서 가져올 파일의 경로를 찾아 입력하면 됩니다.
# 이때, 내가 주인이 아닌 공유폴더는 인식하지 못하는 경우가 있는 것 같아서, 자기 폴더로 사본 복사(꼭!)한 후 사용하시면 될 것 같아요.

juhee_musinsa = pd.read_csv('/content/drive/MyDrive/제로베이스/제로베이스 머신러닝 프로젝트/csv 폴더 모음/크롤링 데이터 240119/[김주희]musinsa_상의_240119.csv', index_col=0)
juhee_musinsa.tail(2)
# Out:
#     major_category middle_category                                    name  \
# 448             상의          니트/스웨터              BLACK PLANET 자카드 니트[BLACK]
# 449             상의          니트/스웨터  코튼 하프 집업 베이지 립 스웨터 (T32D7KTO41TWT1YBH)
#
#                 number  limit  exclusive  target_gender  buy_gender  \
# 448              BLACK      0          0              0         1.0
# 449  T32D7KTO41TWT1YBH      0          0              1         NaN
#
#            buy_age    view  like     price  discount_rate  delivery_date  \
# 448  ('19~23세', 0)  5400.0  2232   54900.0             20              6
# 449    ('~18세', 0)   850.0   657  145600.0             30              5
#
#      rating  review    buy
# 448     4.7      75  500.0
# 449     4.8       4    NaN

# %%
jihyun_musinsa = pd.read_csv('/content/drive/MyDrive/제로베이스/제로베이스 머신러닝 프로젝트/csv 폴더 모음/크롤링 데이터 240119/[김지현]musinsa_상의_240119.csv', index_col=0)
jihyun_musinsa.tail(2)
# Out:
#     major_category middle_category                          name  \
# 358             상의       맨투맨/스웨트셔츠               레터링 그래픽 맨투맨_브라운
# 359             상의         민소매 티셔츠  G CLASSIC SHORT TANK (BLACK)
#
#            number  limit  exclusive  target_gender  buy_gender        buy_age  \
# 358  KBCFUTL100BR      1          0              2         1.0  ('19~23세', 0)
# 359  GY23CLASL001      0          0              1         1.0  ('24~28세', 0)
#
#        view  like    price  discount_rate  delivery_date  rating  review   buy
# 358  1600.0  1012  53100.0             10           19.0     4.9      15  50.0
# 359  1100.0   928  30400.0             20            5.0     4.9      21  50.0

# %%
byungchan_musinsa = pd.read_csv('/content/drive/MyDrive/제로베이스/제로베이스 머신러닝 프로젝트/csv 폴더 모음/크롤링 데이터 240119/[이병찬]musinsa_하의_240119.csv', index_col=0)
byungchan_musinsa.tail(2)
# Out:
#      Unnamed: 0 major_category middle_category                name  \
# 178         178             바지           데님 팬츠  그레이시 버튼 다운 스트레이트 진
# 179         179             바지            숏 팬츠           세레스 셋업 쇼츠
#
#            number  limit  exclusive  target_gender  buy_gender buy_age  view  \
# 178    ND1BPT07GY      0          0              1         NaN  (0, 0)   NaN
# 179  LV19SSPT06SA      0          0              1         NaN  (0, 0)   NaN
#
#      like     price  discount_rate  delivery_date  rating  review  buy
# 178     7  109000.0              0            5.0     NaN       0  NaN
# 179     4   91000.0              0            5.0     NaN       0  NaN

# %%
# jahee_musinsa = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ml_project1/csv/[이자희]musinsa_하의_240118.csv', index_col=0)
# jahee_musinsa.tail(2)
# Out:
#     major_category middle_category                    name      number  limit  \
# 448             바지           코튼 팬츠  [쿨린넨] 원턱 와이드 린넨 팬츠_네이비  5001468115      0
# 449             바지            숏 팬츠             컬러 데님반바지_라임     5138313      0
#
#      exclusive  target_gender  buy_gender        buy_age   view  like  \
# 448          0              0         0.0  ('24~28세', 0)  800.0   260
# 449          0              1         NaN         (0, 0)    NaN     8
#
#        price  discount_rate  delivery_date  rating  review    buy
# 448  32900.0             44              5     4.8      77  100.0
# 449  69000.0              0              5     NaN       0    NaN

# %%
chungha_musinsa = pd.read_csv('/content/drive/MyDrive/제로베이스/제로베이스 머신러닝 프로젝트/csv 폴더 모음/크롤링 데이터 240119/[이청하]musinsa_아우터_240119.csv')
chungha_musinsa.tail(2)
# Out:
#     major_category middle_category  \
# 447            아우터          패딩 베스트
# 448            아우터          환절기 코트
#
#                                                  name           number  limit  \
# 447  [Reversible] Fleece & Padded Vest V2 Light Khaki              504      1
# 448                    CHEST DOUBLE POCKET COAT_BEIGE  20BAFWOCTU001BE      0
#
#      exclusive  target_gender  buy_gender        buy_age    view  like  \
# 447          0              2         0.0  ('29~33세', 0)  1200.0   370
# 448          0              0         0.0    ('40세~', 0)  2200.0   227
#
#        price  discount_rate  delivery_date  rating  review   buy
# 447  38000.0             52            5.0     4.8      18  50.0
# 448  39800.0             80            5.0     5.0      15  50.0

# %%
seunghyun_musinsa = pd.read_csv('/content/drive/MyDrive/제로베이스/제로베이스 머신러닝 프로젝트/csv 폴더 모음/크롤링 데이터 240119/[하승현]musinsa_아우터_240119.csv', index_col=0)
seunghyun_musinsa.tail(2)
# Out:
#    major_category middle_category                name         number  limit  \
# 88            아우터      레더/라이더스 재킷  비건 레더 싱글 카 코트 (블랙)  CXC2JK06K-BLK      0
# 89            아우터          패딩 베스트       컴포트 베스트_BROWN             BR      0
#
#     exclusive  target_gender  buy_gender        buy_age    view  like  \
# 88          0              2         NaN  ('29~33세', 0)  1000.0   500
# 89          0              0         NaN  ('24~28세', 0)  1700.0   154
#
#        price  discount_rate  delivery_date  rating  review  buy
# 88  175500.0             10            5.0     4.8      20  NaN
# 89  193000.0              0            5.0     4.9      25  NaN

# %%
musinsa = pd.read_csv('/content/drive/MyDrive/제로베이스/제로베이스 머신러닝 프로젝트/csv 폴더 모음/크롤링 데이터 240118/musinsa_240119.csv', index_col=0)
musinsa.shape
# Out:
# (5815, 17)

# %%
df = pd.concat([juhee_musinsa, jihyun_musinsa, byungchan_musinsa, musinsa, chungha_musinsa, seunghyun_musinsa])
df = df[['major_category', 'middle_category', 'name', 'number', 'limit', 'exclusive', 'target_gender', 'buy_gender', 'buy_age', 'view', 'like', 'price', 'discount_rate', 'delivery_date', 'rating', 'review', 'buy']]
df.reset_index(drop=True, inplace=True)
df
# Out:
#      major_category middle_category                                   name  \
# 0                상의         셔츠/블라우스               오버사이즈 16골 에센셜 코듀로이 셔츠 블랙
# 1                상의          니트/스웨터             TD5-SW01 램스울 라운드 니트-만다린오렌지
# 2                상의          후드 티셔츠         [SET UP] PPP 플라워 후드 셋업_멜란지 그레이
# 3                상의          후드 티셔츠                TIE DYE 후드티 Olive Green
# 4                상의         긴소매 티셔츠   essential turtleneck logo top - pink
# ...             ...             ...                                    ...
# 8043            아우터     숏패딩/숏헤비 아우터                        숏 미니멀 덕다운 패딩 블랙
# 8044            아우터          아노락 재킷  Pocket Tidy Hood Anorak H7 Navy/Green
# 8045         스포츠/용품             아우터                아웃런 더 스톰 재킷 1376794-002
# 8046            아우터      레더/라이더스 재킷                     비건 레더 싱글 카 코트 (블랙)
# 8047            아우터          패딩 베스트                          컴포트 베스트_BROWN
#
# ...

# %%
df = df.drop_duplicates()

# %%
df.to_csv('/content/drive/MyDrive/제로베이스/제로베이스 머신러닝 프로젝트/csv 폴더 모음/크롤링 데이터 240119/musinsa_240119.csv')

# %% [markdown]
# # review

# %%
juhee_review = pd.read_csv('/content/drive/MyDrive/제로베이스/제로베이스 머신러닝 프로젝트/csv 폴더 모음/크롤링 데이터 240119/[김주희]review_상의_240119.csv', index_col=0)
juhee_review.head(2)
# Out:
#               product_names product_ids user_names  user_ratings  \
# 0  오버사이즈 16골 에센셜 코듀로이 셔츠 블랙  22FWGS28BK        킴오복            80
# 1  오버사이즈 16골 에센셜 코듀로이 셔츠 블랙  22FWGS28BK        web           100
#
#                                         user_reviews
# 0                         깔끔하고 입기 편안해요 손이 자주가는 편한 느낌
# 1  오버한 사이즈고 입으면 더 예쁩니다. 부드럽고 적당한 두께감이라 겨울에 아주 잘입을...

# %%
jihyun_review = pd.read_csv('/content/drive/MyDrive/제로베이스/제로베이스 머신러닝 프로젝트/csv 폴더 모음/크롤링 데이터 240119/[김지현]review_상의_240119.csv', index_col=0)
jihyun_review.head(2)
# Out:
#                     product_names  product_ids user_names  user_ratings  \
# 0  남 블랙 하프 집업 풀오버 스웨터 J325481 BEH  J325481 BEH        대메갓           100
# 1  남 블랙 하프 집업 풀오버 스웨터 J325481 BEH  J325481 BEH        대메갓           100
#
#                                         user_reviews
# 0  평범하신분들한테는 좀 클거같습니다. 소재는 면인데 솔직히 한두번 빨래하면 금방 보풀...
# 1  평범하신분들한테는 좀 클거같습니다. 소재는 면인데 솔직히 한두번 빨래하면 금방 보풀...

# %%
byungchan_review = pd.read_csv('/content/drive/MyDrive/제로베이스/제로베이스 머신러닝 프로젝트/csv 폴더 모음/크롤링 데이터 240119/[이병찬]review_하의_240119.csv', index_col=0)
byungchan_review.head(2)
# Out:
#    Unnamed: 0    product_names product_ids user_names  user_ratings  \
# 0           0  라인 와이드 반바지-머스타드    21063001      또도도가스           100
# 1           1  라인 와이드 반바지-머스타드    21063001      또도도가스           100
#
#                                         user_reviews
# 0        안입은것 마냥 가볍구 편해요. 편함 진짜 편함!! 여름 데일리 바지로 좋아요.
# 1  사이즈 클거 예상했지만, 그럼에도 불구하고 색상에 꽂혀서, 이번 여름 데일리로 입을...

# %%
# jahee_review = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ml_project1/csv/[이자희]review_하의_240118.csv', index_col=0)
# jahee_review.head(2)
# Out:
#     product_names product_ids user_names  user_ratings  \
# 0  마케 팬츠 Short 남성     1114072       내일의듀           100
# 1  마케 팬츠 Short 남성     1114072       빼미팀장           100
#
#                                         user_reviews
# 0  등산의류계의 명품 룬닥스 그중에서도 유명한 마케팬츠 받자마자 너무예쁘다란 생각이 딱...
# 1  워낙 유명한 제품이지만 가격때문에 고민하다가 큰맘먹고 주문했습니다4계절 가능하다고 ...

# %%
chungha_review = pd.read_csv('/content/drive/MyDrive/제로베이스/제로베이스 머신러닝 프로젝트/csv 폴더 모음/크롤링 데이터 240119/[이청하]review_아우터_240119.csv')
chungha_review.head(2)
# Out:
#                product_names   product_ids user_names  user_ratings  \
# 0  브라운 맥시 체스터 코트 (PDHAX7006)     PDHAX7006      키위쥬스님           100
# 1      THREE RIBBON CARDIGAN  IBC23WCD05BK     ALPETA           100
#
#                                         user_reviews
# 0  이쁘네요 잘입겠습니다 핏도 이쁘고 전체적으로 만족합니다. 색감도 제취향이에요 너무 ...
# 1  리본에 잠식된 패션계...입으면 바디라인이 슬림해보이고 분홍 리본이 포인트가 되어줍니다~

# %%
seunghyun_review = pd.read_csv('/content/drive/MyDrive/제로베이스/제로베이스 머신러닝 프로젝트/csv 폴더 모음/크롤링 데이터 240119/[하승현]review_아우터_240119.csv', index_col=0)
seunghyun_review.head(2)
# Out:
#                               product_names product_ids user_names  \
# 0                        하프집업 플리스 아노락 [네이비]  AB5YTP33NV     mh1244
# 0  WOOL TWEED WESTERN TRUCKER JACKET (GREY)   gfw2201gy     아름다운소년
#
#    user_ratings                             user_reviews
# 0           100  음..  가격이 조금 비싸지 않나... 싶은데 막 입기는 괜찮은것같아요
# 0           100        잘받았습니다 디자인도 예쁘고 사이즈도 적당해서 마음에 듭니다

# %%
review = pd.read_csv('/content/drive/MyDrive/제로베이스/제로베이스 머신러닝 프로젝트/csv 폴더 모음/크롤링 데이터 240118/review_240119.csv', index_col=0)
review.tail()
# Out:
#            product_names product_ids user_names  user_ratings  \
# 138150  헌팅 자켓_SPJJD49M02  SPJJD49M02      sktds           100
# 138151  헌팅 자켓_SPJJD49M02  SPJJD49M02     아아너무없다           100
# 138152  헌팅 자켓_SPJJD49M02  SPJJD49M02     콤프라치코스           100
# 138153  헌팅 자켓_SPJJD49M02  SPJJD49M02      kasai           100
# 138154  헌팅 자켓_SPJJD49M02  SPJJD49M02    chamrin           100
#
#                                              user_reviews
# 138150                         배송도 빠르고 만족스럽습니다.싸게 사서 좋아요.
# 138151                          95치고는 살짝큰편 옷이 견고하고 튼튼한 느낌
# 138152    요즘 헌팅자켓이 유행이라하여 구매.디자인 이쁘고 색감 너무 좋고역시 스파오는 가성비갑
# 138153                    생각보다 저렴하도 핏도 만족스러웠어요 다음에도 구매할게요
# 138154  보통 105 입는데 이 자켓은 100 샀는데도 충분히 컸습니다! 화면으로 보는 거보...

# %%
review_df = pd.concat([juhee_review, jihyun_review, byungchan_review, review, chungha_review, seunghyun_review])
review_df.reset_index(drop=True, inplace=True)
review_df
# Out:
#                                             product_names    product_ids  \
# 0                                오버사이즈 16골 에센셜 코듀로이 셔츠 블랙     22FWGS28BK
# 1                                오버사이즈 16골 에센셜 코듀로이 셔츠 블랙     22FWGS28BK
# 2                                오버사이즈 16골 에센셜 코듀로이 셔츠 블랙     22FWGS28BK
# 3                                오버사이즈 16골 에센셜 코듀로이 셔츠 블랙     22FWGS28BK
# 4                                오버사이즈 16골 에센셜 코듀로이 셔츠 블랙     22FWGS28BK
# ...                                                   ...            ...
# 179870  UNISEX Vegan Leather Goose-Down Puffer Blouson...  MS22FWUJK01BK
# 179871  UNISEX Vegan Leather Goose-Down Puffer Blouson...  MS22FWUJK01BK
# 179872  UNISEX Vegan Leather Goose-Down Puffer Blouson...  MS22FWUJK01BK
# 179873  UNISEX Vegan Leather Goose-Down Puffer Blouson...  MS22FWUJK01BK
# 179874  UNISEX Vegan Leather Goose-Down Puffer Blouson...  MS22FWUJK01BK
#
#              user_names  user_ratings  \
# 0                   킴오복            80
# ...

# %%
review_df = review_df.drop_duplicates()

# %%
review_df.to_csv('/content/drive/MyDrive/제로베이스/제로베이스 머신러닝 프로젝트/csv 폴더 모음/크롤링 데이터 240119/review_240119.csv')

# %%
review_df.shape
# Out:
# (143562, 6)

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
